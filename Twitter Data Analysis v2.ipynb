# %% [markdown]
# ## Twitter Data Analysis
#
# @author Swati Singh
#
# This code analyzes captured data from Twitter during SuperBowl 2019. The twitter data was extracted from its API using certain keywords and stored in JSON format. The code below transforms the JSON data into pandas dataframe for further analysis.
#
# Github: https://github.com/swatisingh0107
#
# ### Remaining Things to do
# 1. Extract hashtags from text column and store in a separate column in dataframe
# 2. Fetch wordcloud for most discussed brandnames.
# 3. Clean up text column to remove hyperlinks, hashtags and mentions.
# 4. Perform time series analysis of tweets\
# 5. Perform geographic analysis of tweets
#
# First we are going to load the Twitter JSOn file into a variable JSONdata

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\swati\\Google Drive\\Superbowl'

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
JSONdata='C:\\Users\\swati\\Google Drive\\Superbowl\\SuperbowlJS.json'

# %% [markdown]
# ### Read JSON data to a list
# Now we will read twitter JSON file into a list 'tweets'. Please note Twitter JSON is encoded using UTF-8 characters. Hence the parser should be able to decode the JSON file accurately.

# %%
tweets = []
with open(JSONdata,'r',encoding="utf8") as f:
    tweets = [json.loads(line) for line in f]

# %% [markdown]
# Print text in second row.

# %%
 tweets[1]['text']
# Out:
# 'RT @IAStartingLine: Bud Light has now finished last in the Iowa Caucus https://t.co/hUUjmX62to'

# %% [markdown]
# ### Total number of records

# %%
len(tweets)
# Out:
# 1000

# %% [markdown]
# ### Understanding JSON structure of tweet data
# Now we will look at the structure of the JSON to look for relevant keys that we will use for analysis.

# %%
import json
tweet = tweets[6]
print(json.dumps(tweet, indent=4))
# Out:
# {
#     "_id": {
#         "$oid": "5c57b5f92cec0f358301cf6d"
#     },
#     "quote_count": 0,
#     "contributors": null,
#     "truncated": false,
#     "text": "RT @GameOfThrones: .@TheBudKnight\u2019s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight https://t.co/SzhvDcNAaL",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "reply_count": 0,
#     "id": {
#         "$numberLong": "1092261582329995269"
#     },
#     "favorite_count": 0,
#     "entities": {
#         "user_mentions": [
#             {
#                 "id": 180463340,
#                 "indices": [
#                     3.0,
#                     17.0
#                 ],
#                 "id_str": "180463340",
#                 "screen_name": "GameOfThrones",
#                 "name": "Game Of Thrones"
#             },
#             {
#                 "id": {
#                     "$numberLong": "942879856160800768"
#                 },
#                 "indices": [
#                     20.0,
#                     33.0
#                 ],
#                 "id_str": "942879856160800768",
#                 "screen_name": "TheBudKnight",
#                 "name": "Bud Knight"
#             },
#             {
#                 "id": 742011151,
#                 "indices": [
#                     93.0,
#                     102.0
#                 ],
#                 "id_str": "742011151",
#                 "screen_name": "budlight",
#                 "name": "Bud Light"
#             }
#         ],
#         "symbols": [],
#         "hashtags": [
#             {
#                 "indices": [
#                     70.0,
#                     83.0
#                 ],
#                 "text": "ForTheThrone"
#             },
#             {
#                 "indices": [
#                     85.0,
#                     92.0
#                 ],
#                 "text": "SBLIII"
#             }
#         ],
#         "urls": [],
#         "media": [
#             {
#                 "additional_media_info": {
#                     "monetizable": false,
#                     "embeddable": true,
#                     "description": "",
#                     "title": ""
#                 },
#                 "source_user_id": 180463340,
#                 "source_status_id_str": "1092215925653286914",
#                 "expanded_url": "https://twitter.com/GameOfThrones/status/1092215925653286914/video/1",
#                 "display_url": "pic.twitter.com/SzhvDcNAaL",
#                 "url": "https://t.co/SzhvDcNAaL",
#                 "media_url_https": "https://pbs.twimg.com/media/DyhLbnKWoAAZxBU.jpg",
#                 "source_user_id_str": "180463340",
#                 "source_status_id": {
#                     "$numberLong": "1092215925653286914"
#                 },
#                 "id_str": "1092205231209877505",
#                 "sizes": {
#                     "large": {
#                         "h": 1080,
#                         "resize": "fit",
#                         "w": 1920
#                     },
#                     "small": {
#                         "h": 383,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "medium": {
#                         "h": 675,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "indices": [
#                     103.0,
#                     126.0
#                 ],
#                 "type": "photo",
#                 "id": {
#                     "$numberLong": "1092205231209877505"
#                 },
#                 "media_url": "http://pbs.twimg.com/media/DyhLbnKWoAAZxBU.jpg"
#             }
#         ]
#     },
#     "retweeted": false,
#     "coordinates": null,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "in_reply_to_screen_name": null,
#     "id_str": "1092261582329995269",
#     "retweet_count": 0,
#     "in_reply_to_user_id": null,
#     "favorited": false,
#     "retweeted_status": {
#         "quote_count": 0,
#         "contributors": null,
#         "truncated": false,
#         "text": ".@TheBudKnight\u2019s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight https://t.co/SzhvDcNAaL",
#         "is_quote_status": false,
#         "in_reply_to_status_id": null,
#         "reply_count": 1100,
#         "id": {
#             "$numberLong": "1092215925653286914"
#         },
#         "favorite_count": 29012,
#         "entities": {
#             "user_mentions": [
#                 {
#                     "id": {
#                         "$numberLong": "942879856160800768"
#                     },
#                     "indices": [
#                         1.0,
#                         14.0
#                     ],
#                     "id_str": "942879856160800768",
#                     "screen_name": "TheBudKnight",
#                     "name": "Bud Knight"
#                 },
#                 {
#                     "id": 742011151,
#                     "indices": [
#                         74.0,
#                         83.0
#                     ],
#                     "id_str": "742011151",
#                     "screen_name": "budlight",
#                     "name": "Bud Light"
#                 }
#             ],
#             "symbols": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         51.0,
#                         64.0
#                     ],
#                     "text": "ForTheThrone"
#                 },
#                 {
#                     "indices": [
#                         66.0,
#                         73.0
#                     ],
#                     "text": "SBLIII"
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "additional_media_info": {
#                         "monetizable": false,
#                         "embeddable": true,
#                         "description": "",
#                         "title": ""
#                     },
#                     "expanded_url": "https://twitter.com/GameOfThrones/status/1092215925653286914/video/1",
#                     "display_url": "pic.twitter.com/SzhvDcNAaL",
#                     "url": "https://t.co/SzhvDcNAaL",
#                     "media_url_https": "https://pbs.twimg.com/media/DyhLbnKWoAAZxBU.jpg",
#                     "id_str": "1092205231209877505",
#                     "sizes": {
#                         "large": {
#                             "h": 1080,
#                             "resize": "fit",
#                             "w": 1920
#                         },
#                         "small": {
#                             "h": 383,
#                             "resize": "fit",
#                             "w": 680
#                         },
#                         "medium": {
#                             "h": 675,
#                             "resize": "fit",
#                             "w": 1200
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "indices": [
#                         84.0,
#                         107.0
#                     ],
#                     "type": "photo",
#                     "id": {
#                         "$numberLong": "1092205231209877505"
#                     },
#                     "media_url": "http://pbs.twimg.com/media/DyhLbnKWoAAZxBU.jpg"
#                 }
#             ]
#         },
#         "retweeted": false,
#         "coordinates": null,
#         "source": "<a href=\"https://studio.twitter.com\" rel=\"nofollow\">Twitter Media Studio</a>",
#         "in_reply_to_screen_name": null,
#         "id_str": "1092215925653286914",
#         "display_text_range": [
#             0.0,
#             83.0
#         ],
#         "retweet_count": 11453,
#         "in_reply_to_user_id": null,
#         "favorited": false,
#         "user": {
#             "follow_request_sent": null,
#             "profile_use_background_image": true,
#             "default_profile_image": false,
#             "id": 180463340,
#             "default_profile": false,
#             "verified": true,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1062359744818659328/iI2qrmyl_normal.jpg",
#             "profile_sidebar_fill_color": "0D0D0D",
#             "profile_text_color": "828282",
#             "followers_count": 7303803,
#             "profile_sidebar_border_color": "000000",
#             "id_str": "180463340",
#             "profile_background_color": "000000",
#             "listed_count": 16422,
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "utc_offset": null,
#             "statuses_count": 60521,
#             "description": "All #ForTheThrone. \n#GameofThrones is now available on @HBO.",
#             "friends_count": 39670,
#             "location": "HBO",
#             "profile_link_color": "ABB8C2",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1062359744818659328/iI2qrmyl_normal.jpg",
#             "following": null,
#             "geo_enabled": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/180463340/1542121319",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "name": "Game Of Thrones",
#             "lang": "en",
#             "profile_background_tile": false,
#             "favourites_count": 8709,
#             "screen_name": "GameOfThrones",
#             "notifications": null,
#             "url": "http://ForTheThrone.com",
#             "created_at": "Thu Aug 19 18:04:32 +0000 2010",
#             "contributors_enabled": false,
#             "time_zone": null,
#             "protected": false,
#             "translator_type": "regular",
#             "is_translator": false
#         },
#         "geo": null,
#         "in_reply_to_user_id_str": null,
#         "possibly_sensitive": false,
#         "lang": "en",
#         "created_at": "Mon Feb 04 00:19:03 +0000 2019",
#         "filter_level": "low",
#         "in_reply_to_status_id_str": null,
#         "place": null,
#         "extended_entities": {
#             "media": [
#                 {
#                     "additional_media_info": {
#                         "monetizable": false,
#                         "embeddable": true,
#                         "description": "",
#                         "title": ""
#                     },
#                     "expanded_url": "https://twitter.com/GameOfThrones/status/1092215925653286914/video/1",
#                     "display_url": "pic.twitter.com/SzhvDcNAaL",
#                     "url": "https://t.co/SzhvDcNAaL",
#                     "media_url_https": "https://pbs.twimg.com/media/DyhLbnKWoAAZxBU.jpg",
#                     "video_info": {
#                         "aspect_ratio": [
#                             16.0,
#                             9.0
#                         ],
#                         "duration_millis": 94803,
#                         "variants": [
#                             {
#                                 "url": "https://video.twimg.com/amplify_video/1092205231209877505/vid/320x180/hUEgidVg2tsBNuDW.mp4?tag=9",
#                                 "bitrate": 288000,
#                                 "content_type": "video/mp4"
#                             },
#                             {
#                                 "url": "https://video.twimg.com/amplify_video/1092205231209877505/vid/640x360/Q-SV0iCG2zO0dUbs.mp4?tag=9",
#                                 "bitrate": 832000,
#                                 "content_type": "video/mp4"
#                             },
#                             {
#                                 "url": "https://video.twimg.com/amplify_video/1092205231209877505/vid/1280x720/0Xt_II6R5Xjwhhj3.mp4?tag=9",
#                                 "bitrate": 2176000,
#                                 "content_type": "video/mp4"
#                             },
#                             {
#                                 "url": "https://video.twimg.com/amplify_video/1092205231209877505/pl/BVEsHUo1XmFdI8k6.m3u8?tag=9",
#                                 "content_type": "application/x-mpegURL"
#                             }
#                         ]
#                     },
#                     "id_str": "1092205231209877505",
#                     "sizes": {
#                         "large": {
#                             "h": 1080,
#                             "resize": "fit",
#                             "w": 1920
#                         },
#                         "small": {
#                             "h": 383,
#                             "resize": "fit",
#                             "w": 680
#                         },
#                         "medium": {
#                             "h": 675,
#                             "resize": "fit",
#                             "w": 1200
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "indices": [
#                         84.0,
#                         107.0
#                     ],
#                     "type": "video",
#                     "id": {
#                         "$numberLong": "1092205231209877505"
#                     },
#                     "media_url": "http://pbs.twimg.com/media/DyhLbnKWoAAZxBU.jpg"
#                 }
#             ]
#         }
#     },
#     "user": {
#         "follow_request_sent": null,
#         "profile_use_background_image": true,
#         "default_profile_image": false,
#         "id": 518103929,
#         "default_profile": false,
#         "verified": false,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1009810369605353474/ElFajsrK_normal.jpg",
#         "profile_sidebar_fill_color": "E5507E",
#         "profile_text_color": "362720",
#         "followers_count": 1450,
#         "profile_sidebar_border_color": "FFFFFF",
#         "id_str": "518103929",
#         "profile_background_color": "89C9FA",
#         "listed_count": 20,
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme11/bg.gif",
#         "utc_offset": null,
#         "statuses_count": 48163,
#         "description": "#COYG. Gamer. Ravenclaw . Wampus . Ezrator. I do gameplay on Youtube \u2764\ufe0f\ud83d\udd96\ud83c\udffb. Your Superheroes Fan Girl ;) . TRAVELER 9272 \u2764\ufe0f",
#         "friends_count": 1279,
#         "location": "Earth 616",
#         "profile_link_color": "E81C4F",
#         "derived": {
#             "locations": [
#                 {
#                     "country_code": "US",
#                     "locality": "Black Earth",
#                     "country": "United States",
#                     "region": "Wisconsin",
#                     "sub_region": "Dane County",
#                     "full_name": "Black Earth, Wisconsin, United States",
#                     "geo": {
#                         "type": "point",
#                         "coordinates": [
#                             -89.74679,
#                             43.13722
#                         ]
#                     }
#                 }
#             ]
#         },
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1009810369605353474/ElFajsrK_normal.jpg",
#         "following": null,
#         "geo_enabled": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/518103929/1501006282",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme11/bg.gif",
#         "name": "Commander Shepard",
#         "lang": "en",
#         "profile_background_tile": true,
#         "favourites_count": 6995,
#         "screen_name": "MiharuKenshin",
#         "notifications": null,
#         "url": "https://www.youtube.com/channel/UCuSYvVRYKQEH8uOfg4ZH8Mg",
#         "created_at": "Thu Mar 08 01:47:03 +0000 2012",
#         "contributors_enabled": false,
#         "time_zone": null,
#         "protected": false,
#         "translator_type": "none",
#         "is_translator": false
#     },
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "possibly_sensitive": false,
#     "lang": "en",
#     "matching_rules": [
#         {
#             "tag": null
#         }
#     ],
#     "created_at": "Mon Feb 04 03:20:29 +0000 2019",
#     "filter_level": "low",
#     "in_reply_to_status_id_str": null,
#     "place": null,
#     "extended_entities": {
#         "media": [
#             {
#                 "additional_media_info": {
#                     "monetizable": false,
#                     "embeddable": true,
#                     "description": "",
#                     "title": ""
#                 },
#                 "source_user_id": 180463340,
#                 "source_status_id_str": "1092215925653286914",
#                 "expanded_url": "https://twitter.com/GameOfThrones/status/1092215925653286914/video/1",
#                 "display_url": "pic.twitter.com/SzhvDcNAaL",
#                 "url": "https://t.co/SzhvDcNAaL",
#                 "media_url_https": "https://pbs.twimg.com/media/DyhLbnKWoAAZxBU.jpg",
#                 "source_user_id_str": "180463340",
#                 "source_status_id": {
#                     "$numberLong": "1092215925653286914"
#                 },
#                 "video_info": {
#                     "aspect_ratio": [
#                         16.0,
#                         9.0
#                     ],
#                     "duration_millis": 94803,
#                     "variants": [
#                         {
#                             "url": "https://video.twimg.com/amplify_video/1092205231209877505/vid/320x180/hUEgidVg2tsBNuDW.mp4?tag=9",
#                             "bitrate": 288000,
#                             "content_type": "video/mp4"
#                         },
#                         {
#                             "url": "https://video.twimg.com/amplify_video/1092205231209877505/vid/640x360/Q-SV0iCG2zO0dUbs.mp4?tag=9",
#                             "bitrate": 832000,
#                             "content_type": "video/mp4"
#                         },
#                         {
#                             "url": "https://video.twimg.com/amplify_video/1092205231209877505/vid/1280x720/0Xt_II6R5Xjwhhj3.mp4?tag=9",
#                             "bitrate": 2176000,
#                             "content_type": "video/mp4"
#                         },
#                         {
#                             "url": "https://video.twimg.com/amplify_video/1092205231209877505/pl/BVEsHUo1XmFdI8k6.m3u8?tag=9",
#                             "content_type": "application/x-mpegURL"
#                         }
#                     ]
#                 },
#                 "id_str": "1092205231209877505",
#                 "sizes": {
#                     "large": {
#                         "h": 1080,
#                         "resize": "fit",
#                         "w": 1920
#                     },
#                     "small": {
#                         "h": 383,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "medium": {
#                         "h": 675,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "indices": [
#                     103.0,
#                     126.0
#                 ],
#                 "type": "video",
#                 "id": {
#                     "$numberLong": "1092205231209877505"
#                 },
#                 "media_url": "http://pbs.twimg.com/media/DyhLbnKWoAAZxBU.jpg"
#             }
#         ]
#     }
# }

# %% [markdown]
# ### Example of List item

# %%
tweet['source']
# Out:
# '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>'

# %% [markdown]
# ### Extract retweeted handles.
# The JSON does not reflect the retweeted count as expected. Hence we will use the information from the text to flag tweets that were retweeted.

# %%
for tweet in tweets:
    if 'RT @' in tweet['text']: 
        tweet['retweeted_from'] = tweet['text'].split(':',1)[0]
#         tweet['text']= tweet['text'].split(':',1)[1]
    else:    
        tweet['retweeted_from'] = 'other'

# %% [markdown]
# ### Transform tweets list to a dataframe.
# Exclude key:value pairs that are not required for our analysis.

# %%
column_list=['created_at','id_str','text','retweeted_from','source','retweet_count','favorite_count',
             'screen_name','followers_count','longitude','latitude']

tweet_data = []
for tweet in tweets:
    tweet_data.append([tweet[key] for key in column_list[:-4]])
    tweet_data[-1].append(tweet['user']['screen_name'])
    tweet_data[-1].append(tweet['user']['followers_count'])
#     if 'extended_tweet' in tweet.keys():
#         tweet_data[-1].append(tweet['extended_tweet']['full_text'])
#     else:
#         tweet_data[-1].append("None")
            
    if 'derived' in tweet['user'].keys():
        tweet_data[-1].append(tweet['user']['derived']['locations'][0]['geo']['coordinates'][0])
        tweet_data[-1].append(tweet['user']['derived']['locations'][0]['geo']['coordinates'][1])
    
    
data = pd.DataFrame(tweet_data, columns=column_list)
data.head()
# Out:
#                        created_at               id_str  \
# 0  Mon Feb 04 03:20:19 +0000 2019  1092261543859884032
# 1  Mon Feb 04 03:20:19 +0000 2019  1092261541137780736
# 2  Mon Feb 04 03:20:21 +0000 2019  1092261550738599942
# 3  Mon Feb 04 03:20:22 +0000 2019  1092261555008401409
# 4  Mon Feb 04 03:20:25 +0000 2019  1092261568404967425
#
#                                                                                                                                      text  \
# 0  Best commercial BY FAR was #NFL100 ad. Rest were largely unforgettable or just plain dumb. And so sick of the… https://t.co/BdPtE9y9hq
# 1  RT @IAStartingLine: Bud Light has now finished last in the Iowa Caucus https://t.co/hUUjmX62to
# 2  RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight https://t.co/SzhvDcNAaL
# 3  RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight https://t.co/SzhvDcNAaL
# 4  RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight https://t.co/SzhvDcNAaL
#
#        retweeted_from  \
# 0  other
# 1  RT @IAStartingLine
# 2  RT @GameOfThrones
# 3  RT @GameOfThrones
# 4  RT @GameOfThrones
#
#                                                                                  source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#    retweet_count  favorite_count      screen_name  followers_count  longitude  \
# 0  0              0               MelanieG_Writer  1031            -96.66696
# 1  0              0               CaitrinSneed     456             -87.65005
# 2  0              0               tpalomaresc      72              NaN
# 3  0              0               haileyncrawford  104             NaN
# 4  0              0               jamesmortlock1   14              NaN
#
#    latitude
# 0  40.80000
# 1  41.85003
# 2 NaN
# 3 NaN
# 4 NaN

# %% [markdown]
# ### Drop duplicated records

# %%
data=data.drop_duplicates('id_str')

# %% [markdown]
# ### Total records to be used for analysis

# %%
len(data)
# Out:
# 1000

# %%
import re
data['text']=data['text'].str.replace(r'\bhttps.*','',regex=True)

# %%
pd.set_option('display.max_colwidth', -1)
data['text']
# Out:
# 0      Best commercial BY FAR was #NFL100 ad. Rest were largely unforgettable or just plain dumb. And so sick of the…
# 1      RT @IAStartingLine: Bud Light has now finished last in the Iowa Caucus
# 2      RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 3      RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 4      RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 5      RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 6      RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 7      RT @NerdsSocialClub: BEST COMMERCIAL EVER 😂\n\n#BudLight #GOT #GameOfThrones #ForTheThrone\n\n
# 8      RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 9      @NationalCorn @budlight @millerlight @Coorslite Don’t worry, @realdonaldtrump will bail us all out.
# 10     RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 11     @NationalCorn @DanaPerino @budlight @millerlight @Coorslite This beer commercial was just dumb — waste of money and time
# 12     RT @NationalCorn: .@BudLight America’s corn farmers are disappointed in you. Our office is right down the road! We would love to discuss wi…
# 13     RT @justnbreeden: @NationalCorn @budlight @millerlight @Coorslite This isn’t a @NationalCorn issue, it’s a national health issue
# 14     RT @ThorBjornsson_: In the @GameOfThrones, you win or you die, @TheBudKnight.\n#SBLIII @BudLight
# 15     @Cornfrmr @reinke_farms @CaseyWhite4 @PitstickFarms @TheChadColby @budlight You might agree with a free market, but…
# 16     RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 17     RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 18     RT @NationalCorn: .@BudLight America’s corn farmers are disappointed in you. Our office is right down the road! We would love to discuss wi…
# 19     RT @NationalCorn: .@BudLight America’s corn farmers are disappointed in you. Our office is right down the road! We would love to discuss wi…
# 20     @adamrg #GameOfThrones and #BudLight second
# 21     RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 22     RT @NationalCorn: .@BudLight America’s corn farmers are disappointed in you. Our office is right down the road! We would love to discuss wi…
# 23     RT @ThorBjornsson_: In the @GameOfThrones, you win or you die, @TheBudKnight.\n#SBLIII @BudLight
# 24     RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 25     @NationalCorn @DanaPerino @budlight @millerlight @Coorslite Eat a bowl of dicks corn farmers. You already infest ev…
# 26     @CoachHansen05 @budlight NFL 100 was the most entertaining part of the night
# 27     @HeatherNews8 @budlight @CBS8 Nope
# 28     Bud Light has always been my go to. Not anymore. @budlight. What’s up @CoorsLight ?
# 29     RT @zapman62: @budlight Thanks @budlight for alienating about 90% of your agricultural customers who formerly bought Bud Light.  I will be…
#                                                                           ...
# 970    RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 971    @Nittany99 @budlight It's never been a secret.
# 972    RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 973    RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 974    @budlight brewed by wind power
# 975    RT @GameOfThrones: .@TheBudKnight fought valiantly\n@TheBudKnight fought nobly\n@TheBudKnight fought honorably.\nAnd @TheBudKnight died.\n@BudL…
# 976    RT @barrettpayden: And that's why your beer sucks
# 977    @GameOfThrones @TheBudKnight @budlight WHERE IS THE TRAILER?
# 978    I thought Tom Brady’s post game was another #Budlight commercial. #SuperBowl2019 #SBLlll
# 979    RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 980    RT @performanceagin: Well @budlight you just outcasted the American Farmer good luck with that. I would fire your ad company and do damage…
# 981    RT @budlight: .@Patriots fans, congratulations.  \nYou won the #SuperBowl. \nWe’re bringing the beer.\nBring your 21+ friends and join us alon…
# 982    @GameOfThrones @TheBudKnight @budlight Bud has the money and HBO has the perfect theme to spend it on!
# 983    RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 984    RT @NationalCorn: .@BudLight America’s corn farmers are disappointed in you. Our office is right down the road! We would love to discuss wi…
# 985    I'd love a side story in the final season of Game of Thrones that gives a backstory for the bud knight since they'r…
# 986    @GameOfThrones @TheBudKnight @budlight He's on Arya's list
# 987    @rodgrisier1958 @Indyfarmer @budlight Bulleit bourbon old fashion is my go to these days!
# 988    RT @NationalCorn: .@BudLight America’s corn farmers are disappointed in you. Our office is right down the road! We would love to discuss wi…
# 989    RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 990    Hey, did you guys know - @budlight doesn’t brew with corn syrup? 🤦🏻‍♀️😂🤷🏻‍♀️ #SuperBowlLlll #SuperBowlAds
# 991    RT @NationalCorn: .@BudLight America’s corn farmers are disappointed in you. Our office is right down the road! We would love to discuss wi…
# 992    @budlight @BroncosBudLight #DillyDilly On another (non-GOT subject...what I wouldn't do for a #Broncos #BarrelMan k…
# 993    RT @NationalCorn: .@BudLight America’s corn farmers are disappointed in you. Our office is right down the road! We would love to discuss wi…
# 994    RT @GameOfThrones: .@TheBudKnight fought valiantly\n@TheBudKnight fought nobly\n@TheBudKnight fought honorably.\nAnd @TheBudKnight died.\n@BudL…
# 995    RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 996    @Zimmerman @GameOfThrones @budlight That one was pretty good too. Unexpected for sure.
# 997    @krossfarms @budlight Why did you buy it?
# 998    RT @NerdsSocialClub: BEST COMMERCIAL EVER 😂\n\n#BudLight #GOT #GameOfThrones #ForTheThrone\n\n
# 999    RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# Name: text, Length: 1000, dtype: object

# %% [markdown]
# ### Extract mentions and hashtags from the text

# %%
s=data[data.columns[2]]
type(s)
data['mentions']=s.str.extractall('(\B@\w*)').unstack().apply(lambda x:','.join(x.dropna()), axis=1) 
data['hashtags']=s.str.extractall('(\B#\w*|\B\\n#\w*)').unstack().apply(lambda x:','.join(x.dropna()), axis=1) 
data['hashtags']=data['hashtags'].str.replace('\n','')

# %%
data['hashtags']
# Out:
# 0      #NFL100
# 1      NaN
# 2      #ForTheThrone,#SBLIII
# 3      #ForTheThrone,#SBLIII
# 4      #ForTheThrone,#SBLIII
# 5      #ForTheThrone,#SBLIII
# 6      #ForTheThrone,#SBLIII
# 7      #BudLight,#GOT,#GameOfThrones,#ForTheThrone
# 8      #ForTheThrone,#SBLIII
# 9      NaN
# 10     #ForTheThrone,#SBLIII
# 11     NaN
# 12     NaN
# 13     NaN
# 14     #SBLIII
# 15     NaN
# 16     #ForTheThrone,#SBLIII
# 17     #ForTheThrone,#SBLIII
# 18     NaN
# 19     NaN
# 20     #GameOfThrones,#BudLight
# 21     #ForTheThrone,#SBLIII
# 22     NaN
# 23     #SBLIII
# 24     #ForTheThrone,#SBLIII
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
#       ...
# 970    #ForTheThrone,#SBLIII
# 971    NaN
# 972    #ForTheThrone,#SBLIII
# 973    #ForTheThrone,#SBLIII
# 974    NaN
# 975    NaN
# 976    NaN
# 977    NaN
# 978    #Budlight,#SuperBowl2019,#SBLlll
# 979    #ForTheThrone,#SBLIII
# 980    NaN
# 981    #SuperBowl
# 982    NaN
# 983    #ForTheThrone,#SBLIII
# 984    NaN
# 985    NaN
# 986    NaN
# 987    NaN
# 988    NaN
# 989    #ForTheThrone,#SBLIII
# 990    #SuperBowlLlll,#SuperBowlAds
# 991    NaN
# 992    #DillyDilly,#Broncos,#BarrelMan
# 993    NaN
# 994    NaN
# 995    #ForTheThrone,#SBLIII
# 996    NaN
# 997    NaN
# 998    #BudLight,#GOT,#GameOfThrones,#ForTheThrone
# 999    #ForTheThrone,#SBLIII
# Name: hashtags, Length: 1000, dtype: object

# %% [markdown]
# ### Clean source columns to remove HTML format. Also clean retweeted_from column to remove redundant characters.

# %%
data['source'] = data['source'].str.split('>').str.get(1)
data['source']=data['source'].str.replace('</a','')
data['retweeted_from']=data['retweeted_from'].str.replace('RT @','')

# %% [markdown]
# ### Transform created_at column from string to date-time format

# %%
data['created_at']=pd.to_datetime(data['created_at'])

# %% [markdown]
# ### Keep records captured only during game time

# %%
data=data[(data['created_at']>'2019-02-03 23:29:00') & (data['created_at']<'2019-02-04 04:00:00')]
data.head()
# Out:
#            created_at               id_str  \
# 0 2019-02-04 03:20:19  1092261543859884032
# 1 2019-02-04 03:20:19  1092261541137780736
# 2 2019-02-04 03:20:21  1092261550738599942
# 3 2019-02-04 03:20:22  1092261555008401409
# 4 2019-02-04 03:20:25  1092261568404967425
#
#                                                                                                               text  \
# 0  Best commercial BY FAR was #NFL100 ad. Rest were largely unforgettable or just plain dumb. And so sick of the…
# 1  RT @IAStartingLine: Bud Light has now finished last in the Iowa Caucus
# 2  RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 3  RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 4  RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
#
#    retweeted_from               source  retweet_count  favorite_count  \
# 0  other           Twitter for iPhone   0              0
# 1  IAStartingLine  Twitter for iPhone   0              0
# 2  GameOfThrones   Twitter for Android  0              0
# 3  GameOfThrones   Twitter for iPhone   0              0
# 4  GameOfThrones   Twitter for Android  0              0
#
#        screen_name  followers_count  longitude  latitude  \
# 0  MelanieG_Writer  1031            -96.66696   40.80000
# 1  CaitrinSneed     456             -87.65005   41.85003
# 2  tpalomaresc      72              NaN        NaN
# 3  haileyncrawford  104             NaN        NaN
# 4  jamesmortlock1   14              NaN        NaN
#
#                                  mentions               hashtags
# 0  NaN                                     #NFL100
# 1  @IAStartingLine                         NaN
# 2  @GameOfThrones,@TheBudKnight,@BudLight  #ForTheThrone,#SBLIII
# 3  @GameOfThrones,@TheBudKnight,@BudLight  #ForTheThrone,#SBLIII
# 4  @GameOfThrones,@TheBudKnight,@BudLight  #ForTheThrone,#SBLIII

# %%
len(data)
# Out:
# 1000

# %% [markdown]
# ### Count number of retweets

# %%
retweet_count=data.groupby(['retweeted_from','text']).size().reset_index(name='counts')

# %%
import numpy as np
# count_stat=data.groupby(['retweeted_from'])[["favorite_count","retweet_count"]].sum()
count_stat=data.groupby(['retweeted_from']).agg({'favorite_count':np.sum,'retweet_count':np.sum})
# df.groupby(['Country', 'Item_Code']).agg({'Y1961': np.sum, 'Y1962': [np.sum, np.mean]})  # Added example for two output columns from a single input column
count_stat.head()
#Looks lieke this data is not captured accurately to derive any meaningful information. we will use the next piece 
#of code to count the most retweeted tweet and check most popular brand account
# Out:
#                 favorite_count  retweet_count
# retweeted_from
# 3PercentConf    0               0
# AddictedtoKCMO  0               0
# AltHomelandSec  0               0
# AshyG_          0               0
# BiggestTaco     0               0

# %%
retweet_count.sort_values(['counts'],ascending=False).head()
# Out:
#      retweeted_from  \
# 14  GameOfThrones
# 31  NationalCorn
# 33  NerdsSocialClub
# 45  ThorBjornsson_
# 16  GameOfThrones
#
#                                                                                                                                             text  \
# 14  RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 31  RT @NationalCorn: .@BudLight America’s corn farmers are disappointed in you. Our office is right down the road! We would love to discuss wi…
# 33  RT @NerdsSocialClub: BEST COMMERCIAL EVER 😂\n\n#BudLight #GOT #GameOfThrones #ForTheThrone\n\n
# 45  RT @ThorBjornsson_: In the @GameOfThrones, you win or you die, @TheBudKnight.\n#SBLIII @BudLight
# 16  RT @GameOfThrones: House @BudLight will never forget. #SBLIII #ForTheThrone
#
#     counts
# 14  295
# 31  73
# 33  64
# 45  25
# 16  18

# %% [markdown]
# ### To do: To transform this into a function to return most and least popular tweet

# %%
RT_max=np.max(retweet_count['counts'])
rt=retweet_count[retweet_count.counts==RT_max].index[0]
print("The tweet with more retweets is: \n{}".format(retweet_count['text'][rt]))
print("Number of retweets: {}".format(RT_max))
# Out:
# The tweet with more retweets is:
# RT @GameOfThrones: .@TheBudKnight’s watch has ended.
# What will you do #ForTheThrone?
# #SBLIII @BudLight
# Number of retweets: 295

# %% [markdown]
# ### Most popular twitter sources

# %%
source_count=data.groupby(['source']).size().reset_index(name='counts')
source_count.sort_values(['counts'],ascending=False).head()
# Out:
#                  source  counts
# 14  Twitter for iPhone   597
# 12  Twitter for Android  267
# 11  Twitter Web Client   58
# 10  Twitter Web App      35
# 13  Twitter for iPad     23

# %% [markdown]
# ### Sentiment Analysis

# %%
from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity == 0:
        return 'Neutral'
    else:
        return 'Negative'

# %%
data['SA'] = data['text'].apply(analize_sentiment)

# %%
data.head()
# Out:
#            created_at               id_str  \
# 0 2019-02-04 03:20:19  1092261543859884032
# 1 2019-02-04 03:20:19  1092261541137780736
# 2 2019-02-04 03:20:21  1092261550738599942
# 3 2019-02-04 03:20:22  1092261555008401409
# 4 2019-02-04 03:20:25  1092261568404967425
#
#                                                                                                               text  \
# 0  Best commercial BY FAR was #NFL100 ad. Rest were largely unforgettable or just plain dumb. And so sick of the…
# 1  RT @IAStartingLine: Bud Light has now finished last in the Iowa Caucus
# 2  RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 3  RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
# 4  RT @GameOfThrones: .@TheBudKnight’s watch has ended.\nWhat will you do #ForTheThrone?\n#SBLIII @BudLight
#
#    retweeted_from               source  retweet_count  favorite_count  \
# 0  other           Twitter for iPhone   0              0
# 1  IAStartingLine  Twitter for iPhone   0              0
# 2  GameOfThrones   Twitter for Android  0              0
# 3  GameOfThrones   Twitter for iPhone   0              0
# 4  GameOfThrones   Twitter for Android  0              0
#
#        screen_name  followers_count  longitude  latitude  \
# 0  MelanieG_Writer  1031            -96.66696   40.80000
# 1  CaitrinSneed     456             -87.65005   41.85003
# 2  tpalomaresc      72              NaN        NaN
# 3  haileyncrawford  104             NaN        NaN
# 4  jamesmortlock1   14              NaN        NaN
#
#                                  mentions               hashtags        SA
# 0  NaN                                     #NFL100                Positive
# 1  @IAStartingLine                         NaN                    Positive
# 2  @GameOfThrones,@TheBudKnight,@BudLight  #ForTheThrone,#SBLIII  Neutral
# 3  @GameOfThrones,@TheBudKnight,@BudLight  #ForTheThrone,#SBLIII  Neutral
# 4  @GameOfThrones,@TheBudKnight,@BudLight  #ForTheThrone,#SBLIII  Neutral

# %% [markdown]
# ### Count tweets and handles based on positive and negative sentiment

# %%
#For retweet analysis, we will remove rows where retweeted from is others. These are rows which are actual tweets and not retweets.
retweet = data[data['retweeted_from']!='other']
len(retweet)
# Out:
# 648

# %%
sentiment_count=retweet.groupby(['retweeted_from','text','SA']).size().reset_index(name='counts')

sentiment_count[sentiment_count['counts']>2000].sort_values(['SA','counts'],ascending=False)
# Out:
# Empty DataFrame
# Columns: [retweeted_from, text, SA, counts]
# Index: []

# %%
def tweet_sentiment(sentiment):
    sentiment_data=sentiment_count[(sentiment_count['SA']==sentiment)& (sentiment_count['retweeted_from']!='other')]
    max_sentiment=np.max(sentiment_data['counts'])
    sentiment_index=sentiment_count[sentiment_count.counts==max_sentiment].index[0]
    print("The retweet with most "+ sentiment + " sentiment is: \n{}".format(sentiment_count['text'][sentiment_index])+" \nfrom "+(sentiment_count['retweeted_from'][sentiment_index])+ "\nCount="+str(sentiment_count['counts'][sentiment_index]))
    
tweet_sentiment('Positive')    
print("-----------------------------------------------------------------")
tweet_sentiment('Neutral')
print("-----------------------------------------------------------------")
tweet_sentiment('Negative')
# Out:
# The retweet with most Positive sentiment is:
# RT @NerdsSocialClub: BEST COMMERCIAL EVER 😂
#
# #BudLight #GOT #GameOfThrones #ForTheThrone
#
#
# from NerdsSocialClub
# Count=64
# -----------------------------------------------------------------
# The retweet with most Neutral sentiment is:
# RT @GameOfThrones: .@TheBudKnight’s watch has ended.
# What will you do #ForTheThrone?
# #SBLIII @BudLight
# from GameOfThrones
# Count=295
# -----------------------------------------------------------------
# The retweet with most Negative sentiment is:
# RT @NationalCorn: .@BudLight America’s corn farmers are disappointed in you. Our office is right down the road! We would love to discuss wi…
# from NationalCorn
# Count=73
